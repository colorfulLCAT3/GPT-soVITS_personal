# %% [markdown]
# <a href="https://colab.research.google.com/github/colorfulLCAT3/GPT-soVITS_personal/blob/main/colab_webui3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GPT-SoVITS WebUI

# %% [markdown]
# ## Env Setup (Run Once Only)
# ## 环境配置, 只需运行一次

# %% [markdown]
# ### 1.

# %%
# %%writefile /content/setup.sh
# set -e
#
# cd /content
#
# git clone https://github.com/RVC-Boss/GPT-SoVITS.git
#
# cd GPT-SoVITS
#
# if conda env list | awk '{print $1}' | grep -Fxq "GPTSoVITS"; then
#     :
# else
#     conda create -n GPTSoVITS python=3.10 -y
# fi
#
# source activate GPTSoVITS
#
# pip install ipykernel
#
# bash install.sh --source HF --download-uvr5
# Out:
# Writing /content/setup.sh

# %% [markdown]
# ### 2.

# %%
# %pip install -q condacolab
import condacolab
condacolab.install_from_url("https://repo.anaconda.com/archive/Anaconda3-2024.10-1-Linux-x86_64.sh")
# !cd /content && bash setup.sh
# Out:
# ⏬ Downloading https://repo.anaconda.com/archive/Anaconda3-2024.10-1-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:01:55
# 🔁 Restarting kernel...
# Cloning into 'GPT-SoVITS'...
# remote: Enumerating objects: 5100, done.
# remote: Counting objects: 100% (271/271), done.
# remote: Compressing objects: 100% (211/211), done.
# remote: Total 5100 (delta 136), reused 60 (delta 60), pack-reused 4829 (from 3)
# Receiving objects: 100% (5100/5100), 13.21 MiB | 16.43 MiB/s, done.
# Resolving deltas: 100% (2928/2928), done.
# Channels:
#  - defaults
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/GPTSoVITS
#
#   added / updated specs:
#     - python=3.10
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2025.2.25  |       h06a4308_0         129 KB
# ...

# %% [markdown]
# ## Launch WebUI
# ## 启动 WebUI

# %%
# !cd /content/GPT-SoVITS && source activate GPTSoVITS && export is_share=True && python webui.py
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Running on local URL:  http://0.0.0.0:9874
# Running on public URL: https://bceed5d369bc2d9c93.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# "/usr/local/envs/GPTSoVITS/bin/python" GPT_SoVITS/inference_webui.py "Auto"
# SoVITS_weights_v4/snhv4_2_e3_s261_l128.pth v2 v4 True
# loading sovits_v4pretrained_G <All keys matched successfully>
# loading sovits_v4_lora128
# Removing weight norm...
# loading vocoder <All keys matched successfully>
# Running on local URL:  http://0.0.0.0:9872
# Running on public URL: https://495afd07d98f08b41f.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp -r /content/GPT-SoVITS/GPT_weights_v4 /content/drive/MyDrive/snhv4_2DPO
#!cp -r /content/GPT-SoVITS/SoVITS_weights_v4 /content/drive/MyDrive/snhv4_2
#!cp -r /content/GPT-SoVITS/logs /content/drive/MyDrive/snhv4_2
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)

# %%
# !cp -r /content/GPT-SoVITS/GPT_weights_v41/snhv4_2-e25.ckpt /content/GPT-SoVITS/GPT_weights_v4
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)

# %%
# !cp -r /content/drive/MyDrive/snh_v4/GPT_weights_v4 /content/GPT-SoVITS/GPT_weights_v4
# !cp -r /content/drive/MyDrive/snh_v4/SoVITS_weights_v4 /content/GPT-SoVITS/SoVITS_weights_v4
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)

# %%
# !cp -r /content/drive/MyDrive/snhv4_2/GPT_weights_v4 /content/GPT-SoVITS
# !cp -r /content/drive/MyDrive/snhv4_2/SoVITS_weights_v4 /content/GPT-SoVITS
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)

# %%
# !cp -r /content/GPT-SoVITS/SoVITS_weights_v4 /content/drive/MyDrive/snhv4_2
